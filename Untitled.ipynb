# %% [markdown]
# Objective of Exploratory Data Analysis
# -->To bring out the quality of the data and make it ready for Machine Learning Modeling

# %%
#Import libraries
import numpy as np #Faster Data processing (arrays)
import pandas as pd #EDA Purpose

# %%
# !pip install numpy pandas
# Out:
# ...
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Dell\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Dell\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Dell\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ip (C:\Users\Dell\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages)

# %%
#loading the dta
data = pd.read_csv('titanic.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#understanding the data -->info(),describe(),columns(),unique(),value_counts()
data.info #complete information about dataset
# Out:
# <bound method DataFrame.info of      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ...

# %%
#we will separate the columns
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
#we will separate the columns
data.dtypes
data.select_dtypes(include='object')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12832\2048831057.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ...

# %%
#we will separate the columns
data.dtypes
data.select_dtypes(include='integer')
# Out:
#      PassengerId  Survived  Pclass  SibSp  Parch
# 0              1         0       3      1      0
# 1              2         1       1      1      0
# 2              3         1       3      0      0
# 3              4         1       1      1      0
# 4              5         0       3      0      0
# ..           ...       ...     ...    ...    ...
# 886          887         0       2      0      0
# 887          888         1       1      0      0
# 888          889         0       3      1      2
# 889          890         1       1      0      0
# 890          891         0       3      0      0
#
# [891 rows x 5 columns]

# %%
#we will separate the columns
data.dtypes
data.select_dtypes(include='object')
data.select_dtypes(include=['int','float'])
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12832\3053457780.py:3: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.select_dtypes(include='object')
#      PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0              1         0       3  22.0      1      0   7.2500
# 1              2         1       1  38.0      1      0  71.2833
# 2              3         1       3  26.0      0      0   7.9250
# 3              4         1       1  35.0      1      0  53.1000
# 4              5         0       3  35.0      0      0   8.0500
# ...

# %%
print('total number of passengers in the ship are',len(data))
# Out:
# total number of passengers in the ship are 891

# %%
#statistical distribution -->describe()
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.describe(include='object')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12832\3382516499.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   data.describe(include='object')
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data.describe(include='str')
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
data['Sex'].unique()
# Out:
# <ArrowStringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
data['Embarked'].unique()
# Out:
# <ArrowStringArray>
# ['S', 'C', 'Q', nan]
# Length: 4, dtype: str

# %%
data['Survived'].unique()
# Out:
# array([0, 1])

# %%
data['Parch'].unique()
# Out:
# array([0, 1, 2, 5, 3, 4, 6])

# %%
data['sex'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
data['Sex'].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
data['Servived'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
data['Servived'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# ...

# %%
data['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
data['Pclass'].value_counts()
# Out:
# Pclass
# 3    491
# 1    216
# 2    184
# Name: count, dtype: int64

# %%
data['Age'].value_counts()
# Out:
# Age
# 24.00    30
# 22.00    27
# 18.00    26
# 28.00    25
# 19.00    25
#          ..
# 24.50     1
# 0.67      1
# 0.42      1
# 34.50     1
# 74.00     1
# Name: count, Length: 88, dtype: int64

# %%
data['Age'].value_counts().head(30)
# Out:
# Age
# 24.0    30
# 22.0    27
# 18.0    26
# 28.0    25
# 19.0    25
# 30.0    25
# 21.0    24
# 25.0    23
# 36.0    22
# 29.0    20
# 26.0    18
# 35.0    18
# 27.0    18
# 32.0    18
# 31.0    17
# 16.0    17
# 20.0    15
# 34.0    15
# 33.0    15
# 23.0    15
# 39.0    14
# 40.0    13
# 42.0    13
# 17.0    13
# 45.0    12
# 38.0    11
# 2.0     10
# 4.0     10
# 50.0    10
# 47.0     9
# Name: count, dtype: int64

# %%
data.sample(15)
# Out:
#      PassengerId  Survived  Pclass                               Name     Sex  \
# 688          689         0       3    Fischer, Mr. Eberhard Thelander    male
# 170          171         0       1          Van der hoef, Mr. Wyckoff    male
# 234          235         0       2  Leyson, Mr. Robert William Norman    male
# 771          772         0       3            Jensen, Mr. Niels Peder    male
# 795          796         0       2                 Otter, Mr. Richard    male
# 524          525         0       3                  Kassem, Mr. Fared    male
# 787          788         0       3          Rice, Master. George Hugh    male
# 190          191         1       2                Pinsky, Mrs. (Rosa)  female
# 271          272         1       3       Tornquist, Mr. William Henry    male
# 613          614         0       3                   Horgan, Mr. John    male
# 525          526         0       3                 Farrell, Mr. James    male
# ...

# %%
#datavisualization -->matplotlib,seaborn,plotly
import matplotlib.puplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[27], line 2
#       1 #datavisualization -->matplotlib,seaborn,plotly
# ----> 2 import matplotlib.puplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib.puplot'

# %%
#datavisualization -->matplotlib,seaborn,plotly
import matplotlib.puplot as plt #!pip install matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[28], line 2
#       1 #datavisualization -->matplotlib,seaborn,plotly
# ----> 2 import matplotlib.puplot as plt #!pip install matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib.puplot'

# %%
#datavisualization -->matplotlib,seaborn,plotly
import matplotlib.pyplot as plt #!pip install matplotlib

# %%
plt.hist(data['Age'],bins=15,color='red')
plt.title("Age distribution")
plt.show()

# %%
#display teh count on bars in histogram
#distribution of age
counts,edges,bars=plt.hist(data['Age'],bins=15,color='red')
prints(counts)
prints(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 #display teh count on bars in histogram
#       2 #distribution of age
#       3 counts,edges,bars=plt.hist(data['Age'],bins=15,color='red')
# ----> 4 prints(counts)
#       5 prints(bars)
#       6 plt.xlabel("Age")
#       7 plt.ylabel("Count")
#
# NameError: name 'prints' is not defined

# %%
#display teh count on bars in histogram
#distribution of age
counts,edges,bars=plt.hist(data['Age'],bins=15,color='red')
print(counts)
print(bars)
plt.xlabel("Age")
plt.ylabel("Count")
plt.bar_label(bars)
plt.title("Age distribution")
plt.show()
# Out:
# [ 44.  24.  32. 104. 115. 127.  80.  59.  49.  30.  22.  17.   4.   6.
#    1.]
# <BarContainer object of 15 artists>

# %%
#bar plot representation
data['Sex'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Sex'>

# %%
#bar plot representation
data['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
#bar plot representation
data['Age'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Age'>

# %%
plt.bar(data['Survived'],data['Sex'])
plt.xlabel("Survived Rate")
plt.ylabel("Gender")
plt.title("Gender Survived distribution")
plt.show()

# %%
#549/(549+342)
index=data['Survived'].value_counts().keys().tolist()
print(index)
labels=data['Survived'].value_counts().values.tolist()
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
#pie chart
plt.pie(x=labels,
       labels=['Dead','Alive'],
       colors=['red','yellow'],
       autopct="%.1f%")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 #pie chart
# ----> 2 plt.pie(x=labels,
#       3        labels=['Dead','Alive'],
#       4        colors=['red','yellow'],
#       5        autopct="%.1f%")
#
#     [... skipping hidden 1 frame]
#
# File ~\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
# ...

# %%
plt.pie(x=labels,
       labels=['Dead','Alive'],
       colors=['red','yellow'],
       autopct="%.1f%",
       shadow=True)
plt.title("Survived distribution")
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 plt.pie(x=labels,
#       2        labels=['Dead','Alive'],
#       3        colors=['red','yellow'],
#       4        autopct="%.1f%",
#
#     [... skipping hidden 1 frame]
#
# File ~\OneDrive\Desktop\ML_workshop\ml_workshop_env\Lib\site-packages\matplotlib\pyplot.py:3989, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, hatch, data)
#    3966 @_copy_docstring_and_deprecators(Axes.pie)
#    3967 def pie(
#    3968     x: ArrayLike,
#    (...)   3987     data: DataParamType = None,
#    3988 ) -> PieContainer:
# -> 3989     return gca().pie(
#    3990         x,
#    3991         explode=explode,
#    3992         labels=labels,
#    3993         colors=colors,
# ...

# %%
#pie Chart
plt.pie(x= [577,314],
        labels=['M','F'],
        colors=['blue','pink'],
        autopct="%.1f%%",
       shadow=True)
plt.title("Gender Distribution")
plt.legend()
plt.show()

# %%
#pairwise relationship -->scatterplot()
plt.scatter(x=data['Age'],
           y=data['Fare'])
plt.xlabel("Age")
plt.ylabel("Fare")
plt.tilte("Age vs Fare Distribution")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 6
#       2 plt.scatter(x=data['Age'],
#       3            y=data['Fare'])
#       4 plt.xlabel("Age")
#       5 plt.ylabel("Fare")
# ----> 6 plt.tilte("Age vs Fare Distribution")
#       7 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tilte'

# %%
import plotly

# %%
# !pip install cufflinks
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached setuptools-83.0.0-py3-none-any.whl.metadata (6.6 kB)
# ...
# Using cached setuptools-83.0.0-py3-none-any.whl (1.0 MB)
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68558 sha256=30604c3a85cdbff9084a9d455def652ec6fefe4f318a2e9e4768983512e3ffaa
#   Stored in directory: c:\users\dell\appdata\local\pip\cache\wheels\c0\d9\70\372130dacf508192607c1a7359c7bf0656b1a3b79f6cf66f7a
# Successfully built cufflinks
# ...
#
#    ---------------------------------------- 0/3 [colorlover]
#    ------------- -------------------------- 1/3 [setuptools]
#    ------------- -------------------------- 1/3 [setuptools]
# ...

# %%
import plotly as py
import plotly.graph_objects as go #for interactive graphs

# %%
#Let's visualize 
trace=go.Histogram(x=data['Age'],
                  nbinsx=20,
                  marker={'color':'red'})
#layout define for the graph
layout=go.Layout(title="Age Distribution")
#we combine trace with the layout to display the figure
fig=go.Figure(data=trace,layout=layout)
fig

# %%
print(index)
print(labels)
# Out:
# [0, 1]
# [549, 342]

# %%
#now we will display for piechart
trace=go.Pie(labels=['Dead','Alive'],
            values=[549,342],
            )
layout=go.Layout(title='Survived Distribution')
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
#box plot and scatter plot
trace=go.Box(x=data['Pclass'],
            y=data['Age'],
            marker={'color':'purple'})
layout=go.Layout(title="Age vs Pclass Distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
#scatter plot representation -->age vs fare
trace=go.Scatter(x=data['Age'],y=data['Fare'],
                 mode='markers',
                 marker={'color':'pink'})
layout=go.Layout(
    title="Age vs Fare Distribution")
fig=go.Figure(data=trace,layout=layout)
fig.show()

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#we can fill the age cloumn missing values with mean
data['Age']=data['Age'].fillna(data['Age'].mean())

# %%
data['Age']=data['Age'].fillna(data['Age'].mean(),inplace=True)
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_12832\2347312885.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   data['Age']=data['Age'].fillna(data['Age'].mean(),inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data['Embarked']=data['Embarked'].fillna('S')

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         0
# dtype: int64

# %%
data.drop(columns=['Cabin'],inplace=True)

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64
